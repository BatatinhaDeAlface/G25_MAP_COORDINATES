# %% [markdown]
# # install packages

# %%
# !pip install geopandas matplotlib pandas shapely ipywidgets scipy numpy

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.axes_grid1 import make_axes_locatable
from shapely.geometry import MultiPolygon, Polygon
import ipywidgets as widgets
from ipywidgets import interact
from scipy.interpolate import griddata
import numpy as np

# %% [markdown]
# # Add the coordinates here

# %%
import os

os.environ["TARGET_SAMPLE"] = ""   #Name coord.
os.environ["TARGET_COORDS"] = ""   #Coord.


os.environ["OUTPUT_CSV"]   = r"/distancesG25.csv"
os.chdir(r"/Ficheiros_python")

# !python vahaduo_g25.py

# %% [markdown]
# #### Run this code

# %%
data = pd.read_csv("/distancesG25.csv")

df_genetic = pd.DataFrame(data)

nuts2_map = {
    "Portuguese_central": ["PT19"],
    "Portuguese": ["PT15", "PT1A", "PT1D", "PT1C", "PT30"],
    "Portuguese-2": ["PT11", "PT1B"],
    "Portuguese_Azores": ["PT20"],
    "Spanish": ["ES30", "ES42", "ES43", "ES62", "ES63", "ES64"],
    "Spanish_Andalusia": ["ES61"],
    "Spanish_Canarians": ["ES70"],
    "Spanish_Galicia": ["ES11"],
    "Spanish_Catalan": ["ES51"],
    "Spanish_Valencia": ["ES52"],
    "Spanish_Aragon": ["ES24"],
    "Spanish_Cantabria": ["ES12","ES13"],
    "Spanish_Baleares": ["ES53"],
    "Spanish_North": ["ES22", "ES23", "ES41"],
    "Basque": ["ES21"],
    "Basque_Spain": ["ES21"],
    "Swiss_Italian": ["CH07"],
    "Swiss_German_North": ["CH01","CH02","CH03","CH04","CH05","CH06"],
    "Italian_Tuscany": ["ITI1"],
    "Italian_Aosta": ["ITC2"],
    "Italian_Marche": ["ITI3"],
    "Italian_Veneto": ["ITH3"],
    "Italian_Friuli": ["ITH4"],
    "Italian_Lazio": ["ITI4"],
    "Italian_Apulia": ["ITF4"],
    "Italian_Campania": ["ITF3"],
    "Italian_Calabria": ["ITF6"],
    "Italian_Sicily_Trapani": ["ITG1"],
    "Italian_Sicily_Palermo": ["ITG1"],
    "Italian_Sicily_Ragusa": ["ITG1"],
    "Italian_Sicily_Agrigento": ["ITG1"],
    "Italian_Sicily_Catania": ["ITG1"],
    "Italian_Sicily_Caltanisetta": ["ITG1"],
    "Italian_Sicily_Messina": ["ITG1"],
    "Italian_North": ["ITC1", "ITC3", "ITC4", "ITH1", "ITH2", "ITH5"],
    "Italian_South": ["ITF1", "ITF2", "ITF5", "ITG2"],
    "Italian": ["ITI2"],
    "French_Corsica": ["FRM0"],
    "Basque_France": ["FRI1", "FRI2","FRI3"],
    "French_Rhone-Alpes": ["FRK2"],
    "French_Brittany": ["FRH0"],
    "French_Brittany2": ["FRH0"],
    "French_Southwest": [""],
    "French_South": ["FRL0","FRJ1","FRJ2"],
    "French_Central": ["FRB0", "FRK1"],
    "French_Northeast": ["FRC1", "FRC2","FRD1","FRD2"],
    "French_Northwest": ["FR10","FRE1","FRE2","FRF1","FRF2","FRF3","FRG0"],
    "French-2": ["FR"],
    "French": ["FR"],
    "Guiana_Francesa_medio": ["FRY1", "FRY2", "FRY3", "FRY4", "FRY5"],
    "Albanian_Montenegro": ["AL01"],
    "Albanian_North": ["AL01"],
    "Albanian_Kosovo": ["AL01"],
    "Albanian_South": ["AL03"],
    "Albanian_North_Macedonia": ["AL02"],
    "Albanian": ["AL"],
    "Austrian_Tyrol": ["AT33", "AT34"],
    "Austrian_Salzburg-Upper_Austria": ["AT31", "AT32", "AT13"],
    "Austrian_LowerAustria": ["AT12"],
    "Austrian_Burgenland": ["AT11"],
    "Austrian_Styria": ["AT22"],
    "Austrian_Carinthia": ["AT21"],
    "Greek_Euboea": ["EL52"],
    "Greek_Central-Macedonia": ["EL63"],
    "Greek_Peloponnese": ["EL65"],
    "Greek_Macedonia": ["EL62"],
    "Greek_Thrace": ["EL64"],
    "Greek_Andros": ["EL42"],
    "Greek_Istanbul": ["EL64"],
    "Greek_Cyclades": ["EL42"],
    "Greek_Kythira": ["EL65"],
    "Greek_Central": ["EL51", "EL30"],
    "Greek_NE": ["EL41"],
    "Greek": ["EL43", "EL53", "EL54", "EL61"],
    "North_Macedonian": ["MK00"],
    "North_Macedonian-2": ["MK"],
    "German_Baden-Württemberg": ["DE11", "DE12", "DE13", "DE14"], 
    "German_Bavaria_Lower/Middle_Franconia": ["DE24", "DE25", "DE26"],
    "German_Bavaria_Oberpfalz": ["DE23"],
    "German_Bavaria_proper": ["DE21","DE22"],
    "German_Bavarian_Swabia": ["DE27"],
    "German_Brandenburg_Northwest": ["DE30"],
    "German_Brandenburg_outlier(Beeskow)": ["DE40"],
    "German_County_Glatz": [""],
    "German_East_Prussia_Central": [""],
    "German_East_Prussia_Masuria": [""],
    "German_East_Prussia_Memelland": [""],
    "German_Farther_Pomerania": [""],
    "German_Frisian": ["DEF0"],
    "German_Hesse_South": ["DEB1", "DEB2", "DEB3"],
    "German_Hither_Pomerania": [""],
    "German_Lower_Saxony_North": ["DEG0"],
    "German_Lower_Saxony_South": ["DEG0"],
    "German_Lower_Silesia": ["DEB2", "DEB3"],
    "German_Mecklenburg_Center/East": ["DE50"],
    "German_Mecklenburg_West": ["DE50"],
    "German_North_Bohemia": [""],
    "German_North_Moravia": [""],
    "German_North_Rhine": ["DE91", "DEA1", "DEA2"],
    "German_Rhineland-Palatinate": ["DEA5", "DEB1", "DEB2"],
    "German_Rhineland-Palatinate_East_of_Rhine": ["DEA5"],
    "German_Saarland": ["DEC0"],
    "German_Saxony": ["DE60", "DED2", "DED4", "DED5"],
    "German_Saxony-Anhalt_South": ["DE80"],
    "German_Schleswig-Holstein": ["DEE0"],
    "German_Thuringia_Central": ["DE73"],
    "German_Thuringia_East": ["DE71", "DE72"],
    "German_West_Bohemia": [""],
    "German_West_Prussia": [""],
    "German_Westphalia": ["DE92", "DE93", "DE94", "DEA3", "DEA4"],
    "Montenegrin": ["ME00"],
    "Bulgarian": ["BG31", "BG32", "BG33", "BG34", "BG41", "BG42"],
    "Bulgarian-2": ["BG"],
    "Romanian_Northwest": ["RO11"],
    "Romanian_Southeast": ["RO22", "RO31", "RO42"],
    "Romanian_Southwest": ["RO41"],
    "Romanian_Central": ["RO12"],
    "Romanian_Northeast": ["RO21"],
    "Romanian": ["RO32"],
    "Belgian": ["BE10"],
    "Belgian-2": ["BE31", "BE32", "BE33", "BE34", "BE35"],
    "Flemish": ["BE21", "BE22", "BE23", "BE24", "BE25"],
    "Serb": ["RS11"],
    "Serb-2": ["RS21", "RS22"],
    "Serb_Dalmatia": ["RS12"],
    "Maltese": ["MT00"],
    "Dutch_South": ["NL35", "NL36", "NL41", "NL42"],
    "Dutch": ["NL11", "NL12", "NL13", "NL21", "NL32", "NL35", "NL36", "NL41", "NL42"],
    "Dutch_Central": ["NL22", "NL23", "NL34"],
    "Irish_Leinster": ["IE06"],
    "Irish_Ulster": ["IE04"],
    "Irish_Munster": ["IE05"],
    "Irish_Connacht": ["IE04"],
    "Bosnian": ["BA01", "BA02", "BA03"],
    "Croatian": ['HR02', 'HR03', 'HR05', 'HR06'],
    'Slovenian': ['SI03', 'SI04'],
    "Norwegian-2": ["NO02", "NO09", "NO0A", "NO0B"],
    'Norwegian_North': ["NO06", "NO08"],
    "Norwegian": [""],
    'Saami_Norway': ['NO07'],
    'Slovak': ["SK01"], 
    "Slovak-2": ["SK02","SK03","SK04"],
    'Hungarian': ["HU11", "HU12"], 
    'Hungarian-2': ["HU21", "HU22", "HU23", "HU31", "HU32", "HU33"], 
    'Icelandic': ["IS00"], 
    'Turkish': ['TR10', 'TR21'],
    'Turkish_Kayseri': ['TR71',"TR72"],
    'Turkish_Konya': ['TR33','TR51', "TR52"],
    'Turkish_Sivas': ['TRA1', 'TRA2'],
    'Turkish_Antalya': ["TR61", 'TR62'],
    'Turkish_Aydin': ['TR31', "TR32"],
    'Turkish_Balikesir': ["TR22", 'TR41', 'TR42'],
    'Turkish_Denizli': ['TR81', 'TR82', 'TR83', 'TR90', 'TR63', 'TRB1', 'TRB2', 'TRC1', 'TRC2', 'TRC3'],
    "Cyprus": ["CY00"], 
    'Czech_Bohemia':['CZ02', 'CZ03', 'CZ04', 'CZ05', 'CZ06'],
    'Czech_Moravia': ['CZ07', 'CZ08'],
    'Czech': ["CZ01"],
    'Danish': ['DK01', 'DK02', 'DK03', 'DK04', 'DK05'],
    'Polish_Kashubian': ["PL63"],
    'Polish_Mazovia': ["PL91","PL92"],
    'Polish_North': ["PL42", "PL43", "PL61"],
    'Polish_Podlasie_East_Mazovia': ["PL84","PL72"],
    'Polish_SE_Carpathia': ["PL82"],
    'Polish_South': ["PL21", "PL51", "PL52", "PL81"],
    'Polish_Sudovia': ["PL62"],
    'Polish_Upper_Silesia': ["PL22"],
    'Polish_Wielkopolska': ["PL41"],
    'Polish': ["PL911"],
    'Polish-2': ["PL71", "PL72"],
    'Latvian': ["LV00"],
    'Latvian2': [""],
    'Lithuanian': ['LT01', 'LT02'],
    'Estonian': ["EE00"],
    'Estonian-2': [""],
    
    'Finnish': ["FI1B","FI20"],
    'Finnish_Northeast': ["FI1D"],
    'Finnish_Southeast_Ingria': [""],
    'Finnish_Southwest': ["FI19", "FI1C"],
    
    'Swedish': ['SE11', 'SE12', 'SE21', 'SE22', 'SE23'],
    'Swedish_North': ['SE31', 'SE32'],
    'Saami_Sweden': ['SE33'],
    'Luxembourg': ['LU00'], 
    'Kosovo': ['XK00'],
    'Liechtenstein': ['LI00'],
}
    
Countries_euro_left = {
    
    'Belarusian_East': ["BLR.2_1", "BLR.5_1", "BLR.4_1", "BLR.6_1", "BLR.7_1"],
    'Belarusian_Polesia': ["BLR.1_1"],
    'Belarusian_West': ["BLR.3_1"],
    
    'Ukrainian_Central': ["UKR.1_1", "UKR.4_1", "UKR.5_1", "UKR.10_1", "UKR.11_1", "UKR.12_1", "UKR.13_1", "UKR.18_1", "UKR.20_1", "UKR.24_1", "UKR.27_1"], 
    'Ukrainian_East': ["UKR.2_1", "UKR.6_1", "UKR.8_1", "UKR.9_1", "UKR.15_1", "UKR.16_1","UKR.17_1", "UKR.21_1","UKR.26_1"], 
    'Ukrainian_West': ["UKR.3_1", "UKR.7_1", "UKR.14_1", "UKR.19_1","UKR.22_1", "UKR.23_1", "UKR.25_1"],
    
    "English_East-Midlands": ["E15000004"],
    "English_East": ["E15000006"],
    "English_Lancashire": ["E15000002"],
    "English_Northeast": ["E15000001"],
    "English_Southeast": ["E15000008"],
    "English_Southwest": ["E15000009"],
    "English_West-Midlands": ["E15000005"],
    "English_Yorkshire": ["E15000003"],
    "English_London": ["E15000007"],
    "Cornish": ["E15000009"],
    "Scottish": ["GBR.3_1"],
    "Welsh": ["GBR.4_1"],
    "Northern_Ireland": ["GBR.2_1"],
    
    "Russian": ["RUS.43_1", "RUS.44_1"], 
    'Russian_Bryansk': ["RUS.1_1", "RUS.2_1", "RUS.3_1", "RUS.6_1", "RUS.7_1", "RUS.8_1", "RUS.9_1", "RUS.11_1", "RUS.12_1", "RUS.13_1", "RUS.16_1", "RUS.18_1","RUS.27_1", "RUS.28_1", "RUS.29_1", "RUS.34_1", "RUS.35_1", "RUS.36_1", "RUS.39_1", "RUS.41_1", "RUS.42_1", "RUS.50_1", "RUS.51_1", "RUS.53_1", "RUS.54_1", "RUS.56_1", "RUS.59_1", "RUS.61_1", "RUS.62_1", "RUS.63_1", "RUS.69_1", "RUS.70_1", "RUS.73_1", "RUS.74_1", "RUS.75_1", "RUS.76_1", "RUS.82_1", "RUS.83_1"],
    'Russian_Don_Cossack': ["RUS.5_1", "RUS.10_1", "RUS.15_1", "RUS.17_1", "RUS.20_1", "RUS.22_1", "RUS.25_1", "RUS.65_1", "RUS.66_1", "RUS.68_1", "RUS.71_1", "RUS.77_1"], 
    'Russian_Kirov': ["RUS.31_1"],
    'Russian_Kostroma': ["RUS.33_1"], 
    'Russian_Kursk': ["RUS.37_1"],
    'Russian_Meshchera_Lowlands': ["RUS.19_1", "RUS.23_1","RUS.24_1"],
    'Russian_Nizhny_Novgorod_Yaroslavl': ["RUS.47_1", "RUS.48_1", "RUS.81_1"], 
    'Russian_North': ["RUS.14_1", "RUS.21_1", "RUS.26_1", "RUS.30_1", "RUS.32_1", "RUS.38_1", "RUS.40_1", "RUS.45_1", "RUS.46_1", "RUS.78_1", "RUS.80_1"],
    'Russian_Novgorod_Pskov': ["RUS.49_1", "RUS.57_1", "RUS.58_1"],
    'Russian_Oryol': ["RUS.52_1"],
    'Russian_Perm': ["RUS.55_1"],
    'Russian_Pinega': ["RUS.4_1"], 
    'Russian_Smolensk': ["RUS.64_1"], 
    'Russian_Tambov': ["RUS.67_1"],
    'Russian_Tver': ["RUS.72_1"],
    'Russian_Voronezh': ["RUS.79_1"],
    'Russian_Yakut': ["RUS.60_1"],
    #'Bashkir_Russia': [""],
    #'Tatar_Russia':
    #'Chuvash_Russia':
}

Countries_map = {
    
     'Afghanistan': ['AFG'], #Afghanistan
     'Tunisia': ['TUN'], #Tunisia
     'Algeria': ['DZA'], #Algeria
     'Morocco': ['MAR', 'SAH'], #Morocco, Saara ocidental
     'Libya': ['LBY'], #Lybia
     'Egypt': ['EGY'], #Egypt
     'Syrian': ['SYR'], #Syria
     'Iraqi': ['IRQ'], #Iraq
     'Angola': ['AGO'], #Angola
     #'Antarctica': ['ATA'],
     'Argentino_medio': ['ARG'], #Argentina
     'Armenian': ['ARM'], #Armenia
     'Azerbaijan': ['AZE'], #Azerbaijan
     'Bangladesh': ['BGD'], #Bangladesh
     'Belize_medio': ['BLZ'], #Belize
     'Bolivia': ['BOL'], #Bolivia
     'Brasileiro_medio': ['BRA'], #Brazil
     'Cambodia': ['KHM'], #Cambodia
     'Cameroon': ['CMR'], #Cameroon
     'Canada_medio': ['CAN'], #Canada
     'Chile_medio': ['CHL'], #Chile
     'Chinese': ['CH1'], #China
     'Colombia': ['COL'], #Colombia
     'CostaRica_medio': ['CRI'], #Costa Rica
     'Cuba_medio': ['CU1'], #Cuba
     'Congo': ['COD', 'COG'], #Democratic Republic of the Congo, Republic of the Congo
     'Dominican_Republic': ['DOM'], #Dominican Republic
     'Ecuador': ['ECU'], #Ecuador
     'ElSalvador_medio': ['SLV'], #El Salvador
     'Eritrea': ['ERI'], #Eritrea
     'Ethiopia': ['ETH'], #Ethiopia
     'Gambia': ['GMB'], #Gambia
     'Georgia': ['GEO'], #Georgia
     'Guatemala_medio': ['GTM'], #Guatemala
     'Guiana_medio': ['GUY'], #Guyana
     'Haiti_medio': ['HTI'], #Haiti
     'Honduras_medio': ['HND'], #Honduras
     'Indian': ['IND'], #India
     'Indonesia': ['IDN', 'FJI'], #Indonesia, Fiji 
     'Iran': ['IRN'], #Iran
     'Israel': ['IS1'], #Israel
     'Jamaica_medio': ['JAM'], #Jamaica
     'Japan': ['JPN'], #Japan
     'Kazakhistan': ['KA1'], #Kazakhstan
     'Kenya': ['KEN'], #Kenya
     'Kirghizstan': ['KGZ'], #Kyrgyzstan
     'Laos': ['LAO'], #Laos
     'Saudi_Arabia': ['SAU'], #Saudi_Arabia
     'Lebanon': ['LBN'], #Lebanon
     'Jordanian': ['JOR'], #Jordan
     'Madagascar': ['MDG'], #Madagascar
     'Malaysia': ['MYS'], #Malaysia
     'Mali': ['MLI'], #Mali
     'Mexico': ['MEX'], #Mexico
     'Moldova': ['MDA'], #Moldova
     'Mongolia': ['MNG'], #Mongolia
     'Myanmar': ['MMR'], #Myanmar
     'Nepalese': ['NPL', 'BTN'], #Nepal, Butan
     'Nicaragua_medio': ['NIC'], #Nicaragua
     'Nigeria': ['NGA'], #Nigeria
     'Korea': ['PRK', 'KOR'], #N_korea, S_korea
     'Oman': ['OMN'], #Oman
     'Pakistan': ['PAK'], #Pakistan
     'Panama_medio': ['PAN'], #Panama
     'Papua_New_Guinea': ['PNG', 'VUT', 'SLB'], #Papua New Guinea, Vanuatu, Solomon Islands
     'Paraguai_medio': ['PRY'], #Paraguay
     'Peru': ['PER'], #Peru
     'Central_Filipino': ['PHL'], #Philippines
     #'Russian': ['RUS'], #Russia
     'Somalia': ['SOM', 'SOL'], #Somalia, Somaliland
     'South_Africa': ['ZAF', 'LSO'], #South Africa, lesotho
     'South_Sudan': ['SDS'], #South Sudan
     'Sri_Lanka': ['LKA'], #Sri Lanka
     'Sudan': ['SDN'], #Sudan
     'Taiwan_Indigenous': ['TWN'], #Taiwan
     'Tajikistan': ['TJK'], #Tajikistan
     'Thailand': ['THA'], #Thailand
     'Bahamas_medio': ['BHS'], #The Bahamas
     'Trinidad_medio': ['TTO'], #Trinidad and Tobago
     #'Turkey': ['TUR'],
     'Turkmenistan': ['TKM'], #Turkmenistan
     'United_Arab_Emirates': ['ARE'], #United Arab Emirates
     'USA_medio': ['US1'], #United States of America
     'Uruguai_medio': ['URY'], #Uruguay
     'Uzbekistan': ['UZB'], #Uzbekistan
     'Venezuela_medio': ['VEN'], #Venezuela
     'Vietnam': ['VNM'], #Vietnam
     'Yemen': ['YEM'], #Yemen
      #Benin, Botswana, Burundi, Central African Republic, Djibouti, Equatorial Guinea
      #Ghana, Guinea-Bissau, Ivory Coast, Liberia, 
      #Niger, Suriname, Togo, Zambia
      #Zimbabwe, eSwatini
     'Sub-Saharan_African': ['BEN', 'BWA', 'CAF', 'DJI', 'GNQ', 'GHA', 'GNB', 'CIV', 'LBR',
                             'NER', 'SUR', 'TGO', 'ZMB','ZWE', 'SWZ'], 
     'Chad': ['TCD'],
     'Gabon': ['GAB'],
     'Uganda': ['UGA'],
     'Burundi': ['BDI'],
     'Tanzania': ['TZA'], #United Republic of Tanzania
     'Rwanda': ['RWA'],
     'Malawi': ['MWI'],
     'Namibia': ['NAM'],
     'Mozambique': ['MOZ'],
     'Brunei': ['BRN'],
     'East_Timor': ['TLS'],
     'Mauritania': ['MRT'],
     'Burkina_Faso': ['BFA'],
     'Sierra_Leone': ['SLE'],
     'Guinea': ['GIN'],
     'Senegal': ['SEN'],
     'Kuwait': ['KWT'],
     'Qatar': ['QAT'],
     'English_London': ['NZ1', 'AU1'], #New zealand, Australia
}

# %% [markdown]
# # Generate maps

# %%
rg = gpd.read_file("/ref-nuts-2024-03m.shp/NUTS_RG_03M_2024_4326_LEVL_2.shp")
bn = gpd.read_file("/ref-nuts-2024-03m.shp/NUTS_BN_03M_2024_4326_LEVL_2.shp")
countries = gpd.read_file("/ne_110m_admin_0_sovereignty")
uk_divisions = gpd.read_file("/gadm41_GBR_1.geojson/gadm41_GBR_1.geojson")
files = [
    "/gadm41_GBR_1.geojson/gadm41_GBR_1.geojson",
    "/gadm41_UKR_1.geojson/gadm41_UKR_1.geojson",
    "/gadm41_BLR_1.geojson/gadm41_BLR_1.geojson",
    "/topo_eer.json",
    "/gadm41_RUS_1.json/gadm41_RUS_1.json"
]

gdfs = [gpd.read_file(f) for f in files]
divisions_all = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))
divisions_all["geometry"] = divisions_all.geometry.buffer(0)

bn1 = gpd.read_file("/ref-nuts-2024-03m.shp/NUTS_BN_03M_2024_4326_LEVL_1.shp")
bn2 = gpd.read_file("/ref-nuts-2024-03m.shp/NUTS_BN_03M_2024_4326_LEVL_0.shp")

df_genetic['NUTS2'] = df_genetic['Population'].map(nuts2_map)
df_genetic_exploded = df_genetic.explode('NUTS2')
df_nuts2 = df_genetic_exploded.groupby('NUTS2', as_index=False)['Distance'].mean()

df_genetic_gid = df_genetic.copy()
df_genetic_gid['GID'] = df_genetic_gid['Population'].map(Countries_euro_left)
df_genetic_gid = df_genetic_gid.dropna(subset=['GID'])
df_genetic_exploded_ct1 = df_genetic_gid.explode('GID')
df_country_euro = df_genetic_exploded_ct1.groupby('GID', as_index=False)['Distance'].mean()

df_genetic_country = df_genetic.copy()
df_genetic_country['Country'] = df_genetic_country['Population'].map(Countries_map)
df_genetic_country = df_genetic_country.dropna(subset=['Country'])
df_genetic_exploded_ct = df_genetic_country.explode('Country')
df_country_general = df_genetic_exploded_ct.groupby('Country', as_index=False)['Distance'].mean()

countries = countries.merge(df_country_general, left_on='SOV_A3', right_on='Country', how='left')

divisions_all["merge_id"] = None

if "GID_1" in divisions_all.columns:
    divisions_all.loc[divisions_all["GID_1"].notna(), "merge_id"] = divisions_all["GID_1"]

if "EER13CD" in divisions_all.columns:
    divisions_all.loc[divisions_all["EER13CD"].notna(), "merge_id"] = divisions_all["EER13CD"]

df_all = divisions_all.merge(df_country_euro, left_on='merge_id', right_on='GID', how='left')

rg = rg.merge(df_nuts2, left_on='NUTS_ID', right_on='NUTS2', how='left')

all_distances = pd.concat([rg['Distance'], countries['Distance']]).dropna()

factor = 0.3 
vmin = float(all_distances.min()) * factor if not all_distances.empty else 0.0
vmax = float(all_distances.max()) * factor if not all_distances.empty else 1.0

bn2_filtered = bn2[bn2['LEFT_NUTS3'].notna() & ~bn2['LEFT_NUTS3'].astype(str).str.startswith('FRY')]

countries_with_data = countries[countries['Distance'].notna()]

internal_boundaries = []

for i, geom in enumerate(countries_with_data.geometry):
    for j, other_geom in enumerate(countries_with_data.geometry):
        if i < j:  
            shared = geom.intersection(other_geom)
            if not shared.is_empty:
                internal_boundaries.append(shared)
                
internal_boundaries = gpd.GeoSeries(internal_boundaries, crs=countries_with_data.crs)

ukraine = countries.loc[countries['NAME'] == 'Ukraine'].geometry.values[0]
belarus = countries.loc[countries['NAME'] == 'Belarus'].geometry.values[0]
poland = countries.loc[countries['NAME'] == 'Poland'].geometry.values[0]
russia = countries.loc[countries['NAME'] == 'Russia'].geometry.values[0]
finland = countries.loc[countries['NAME'] == 'Finland'].geometry.values[0]
lithuania = countries.loc[countries['NAME'] == 'Lithuania'].geometry.values[0]
turkey = countries.loc[countries['NAME'] == 'Turkey'].geometry.values[0]
syria = countries.loc[countries['NAME'] == 'Syria'].geometry.values[0]
estonia = countries.loc[countries['NAME'] == 'Estonia'].geometry.values[0]
latvia = countries.loc[countries['NAME'] == 'Latvia'].geometry.values[0]
moldavia = countries.loc[countries['NAME'] == 'Moldova'].geometry.values[0]
romenia = countries.loc[countries['NAME'] == 'Romania'].geometry.values[0]


extra_borders = [
    moldavia.intersection(ukraine),
]

extra_borders = gpd.GeoSeries(
    [b for b in extra_borders if not b.is_empty],
    crs=countries_with_data.crs
)

internal_boundaries = pd.concat([internal_boundaries, extra_borders], ignore_index=True)

internal_borders = []

for i, geom_i in enumerate(uk_divisions.geometry):
    for j, geom_j in enumerate(uk_divisions.geometry):
        if i < j:  
            shared = geom_i.intersection(geom_j)
            if not shared.is_empty:
                internal_borders.append(shared)

internal_borders_gs = gpd.GeoSeries(internal_borders, crs=uk_divisions.crs)


uk_union = uk_divisions.union_all() 

external_border = gpd.GeoSeries([uk_union.boundary], crs=uk_divisions.crs)

codes_from_map = []
for v in Countries_map.values():
    if isinstance(v, list):
        codes_from_map.extend(v)  
    else:
        codes_from_map.append(v)  

countries_filtered = countries[countries['SOV_A3'].isin(codes_from_map)]

countries_union = countries_filtered.union_all()

external_borders_countries = gpd.GeoSeries([countries_union.boundary], crs=countries.crs)

russia_codes = []
for k, v in Countries_euro_left.items():
    if k.startswith("Russian"):  
        russia_codes.extend(v)

russia_divisions = df_all[df_all['GID'].isin(russia_codes)]

russia_union = russia_divisions.union_all()
if isinstance(russia_union, Polygon):
    external_border_russia = gpd.GeoSeries([russia_union.exterior], crs=df_all.crs)
elif isinstance(russia_union, MultiPolygon):
    external_border_russia = gpd.GeoSeries([poly.exterior for poly in russia_union.geoms], crs=df_all.crs)
else:
    external_border_russia = gpd.GeoSeries([], crs=df_all.crs)
    
colormaps = ["Blues_r", "viridis_r", "magma_r", "afmhot_r", "copper_r"]

def plot_map(title, xlim, ylim, base_height=12, figsize=None, savepath=None, cmap="copper_r"):
    if figsize is None:
        width = xlim[1] - xlim[0]
        height = ylim[1] - ylim[0]
        aspect_ratio = width / height
        figsize = (base_height * aspect_ratio, base_height)

    fig, ax = plt.subplots(figsize=figsize)
    ax.set_title(title)
    
    rg.plot(column='Distance', cmap=cmap, ax=ax, legend=True, linewidth=0, edgecolor='none', vmin=vmin, vmax=vmax)

    df_all.plot(column='Distance', cmap=cmap, ax=ax, linewidth=0, edgecolor='none', vmin=vmin, vmax=vmax, alpha=1)

    countries.plot(column='Distance', cmap=cmap, ax=ax, linewidth=0, edgecolor='none', vmin=vmin, vmax=vmax, alpha=1)
    
    bn2_filtered.plot(ax=ax, color='black', linewidth=0.50)
    bn2.plot(ax=ax, color='black', linewidth=0.50)
    external_border.plot(ax=ax, color='black', linewidth=0.50)
    internal_boundaries.plot(ax=ax, color='black', linewidth=0.50)
    internal_borders_gs.plot(ax=ax, color="black", linewidth=0.50)
    external_borders_countries.plot(ax=ax, color="black", linewidth=0.5)
    external_border_russia.plot(ax=ax, color="black", linewidth=0.5)

    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    ax.set_aspect('equal')  

    plt.tight_layout()
    plt.show()

@interact(cmap=colormaps)
def update_maps(cmap):
    # Europa
    plot_map("EUROPE", (-25, 40), (25, 72), cmap=cmap)

    # Ásia
    plot_map("ASIA", (25, 180), (-30, 80), cmap=cmap)

    # África
    plot_map("AFRICA", (-25, 60), (-40, 40), cmap=cmap)

    # América
    plot_map("AMERICA", (-170, -30), (-60, 80), cmap=cmap)

    # Mundo (formato panorâmico)
    plot_map("WORLD", (-180, 180), (-90, 90), figsize=(18, 9), cmap=cmap)

# %% [markdown]
# # Generate Map Density

# %%
rg['centroid'] = rg.geometry.centroid
countries['centroid'] = countries.geometry.centroid

points_nuts2 = pd.DataFrame({
    'lon': rg.centroid.x,
    'lat': rg.centroid.y,
    'Distance': rg.Distance
})

points_country = pd.DataFrame({
    'lon': countries.centroid.x,
    'lat': countries.centroid.y,
    'Distance': countries.Distance
})

points = pd.concat([points_nuts2, points_country]).dropna()

lon_min, lon_max = -25, 40
lat_min, lat_max = 25, 72

grid_lon, grid_lat = np.meshgrid(
    np.linspace(lon_min, lon_max, 600),
    np.linspace(lat_min, lat_max, 400)
)

grid_distance = griddata(
    points[['lon', 'lat']],
    points['Distance'],
    (grid_lon, grid_lat),
    method='linear'
)


def maximize_contrast(x, gamma , log_factor):
    x_norm = (x - np.nanmin(x)) / (np.nanmax(x) - np.nanmin(x))
    x_log = np.log1p(x_norm * log_factor)
    x_log /= np.nanmax(x_log)
    x_contrast = np.power(x_log, gamma)
    return x_contrast
grid_contrast = maximize_contrast(grid_distance,1.5, 600)

colormaps = ["Blues_r", "viridis_r", "magma_r", "afmhot_r", "copper_r"]

def plot_interpolated_map(cmap="Blues_r"):
    fig, ax = plt.subplots(figsize=(12, 12))

    im = ax.imshow(grid_contrast, origin='lower',
                   extent=(lon_min, lon_max, lat_min, lat_max),
                   cmap=cmap, alpha=0.8)

    countries.boundary.plot(ax=ax, color='black', linewidth=0.5)

    ax.set_xlim(lon_min, lon_max)
    ax.set_ylim(lat_min, lat_max)

    plt.colorbar(im, ax=ax)

    plt.tight_layout()
    plt.show()

@interact(cmap=colormaps)
def update_interpolated(cmap):
    plot_interpolated_map(cmap)
